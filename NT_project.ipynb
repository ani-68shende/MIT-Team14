# %%
#/Users/ani/Downloads/Stock List.csv
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
file = open("/Users/ani/Downloads/Stock List.csv")  #reading data from .csv file
df = pd.read_csv(file)
print(df.columns)
# Out:
# Index(['close', 'high', 'low', 'open', 'symbol', 'volume', 'id', 'key',
#        'subkey', 'date', 'updated', 'changeOverTime', 'marketChangeOverTime',
#        'uOpen', 'uClose', 'uHigh', 'uLow', 'uVolume', 'fOpen', 'fClose',
#        'fHigh', 'fLow', 'fVolume', 'label', 'change', 'changePercent'],
#       dtype='object')

# %%
df.dtypes
# Out:
# close                   float64
# high                    float64
# low                     float64
# open                    float64
# symbol                   object
# volume                    int64
# id                       object
# key                      object
# subkey                  float64
# date                     object
# updated                   int64
# changeOverTime          float64
# marketChangeOverTime    float64
# uOpen                   float64
# uClose                  float64
# uHigh                   float64
# uLow                    float64
# uVolume                   int64
# fOpen                   float64
# fClose                  float64
# fHigh                   float64
# fLow                    float64
# fVolume                   int64
# label                    object
# change                  float64
# changePercent           float64
# dtype: object

# %%
df["symbol"].value_counts()
# Out:
# ADSK    163
# INTC    163
# KO      163
# CVX     163
# TSLA    163
#        ...
# AMT     163
# MCD     163
# TGT     163
# AAPL    162
# JNJ     162
# Name: symbol, Length: 102, dtype: int64

# %%
df[df.symbol == "XOM"]
# Out:
#       close    high      low   open symbol    volume                 id  key  \
# 9615  41.50  42.245  41.0000  41.45    XOM  27764696  HISTORICAL_PRICES  XOM
# 9616  43.50  44.800  41.8300  41.84    XOM  44035135  HISTORICAL_PRICES  XOM
# 9617  44.61  45.100  43.7000  44.41    XOM  36484795  HISTORICAL_PRICES  XOM
# 9618  44.96  45.570  44.5300  45.00    XOM  29528115  HISTORICAL_PRICES  XOM
# 9619  45.46  45.820  44.9500  45.20    XOM  28628224  HISTORICAL_PRICES  XOM
# ...     ...     ...      ...    ...    ...       ...                ...  ...
# 9773  52.73  53.705  52.1000  53.47    XOM  30923509  HISTORICAL_PRICES  XOM
# 9774  52.74  53.135  52.1100  52.27    XOM  16918278  HISTORICAL_PRICES  XOM
# 9775  54.91  55.060  53.9500  53.95    XOM  21632614  HISTORICAL_PRICES  XOM
# 9776  55.36  55.850  55.0100  55.29    XOM  17915557  HISTORICAL_PRICES  XOM
# 9777  55.46  55.770  54.8701  55.24    XOM  13270317  HISTORICAL_PRICES  XOM
#
# ...

# %%
#ssort out the companies which have value of high<=300 and value of low>=150
df[(df["high"]<=300) & (df["low"]>=150)]
# Out:
#         close      high       low    open symbol    volume                 id  \
# 162    217.69  223.0000  214.8100  222.53   MSFT  37130139  HISTORICAL_PRICES
# 163    217.90  218.5200  215.7000  217.26   MSFT  23822953  HISTORICAL_PRICES
# 164    212.25  216.4899  211.9400  212.17   MSFT  35930653  HISTORICAL_PRICES
# 165    218.29  219.3400  213.7100  214.04   MSFT  27694480  HISTORICAL_PRICES
# 166    219.62  220.5800  217.0261  218.68   MSFT  22956206  HISTORICAL_PRICES
# ...       ...       ...       ...     ...    ...       ...                ...
# 15900  296.48  297.9000  292.5900  293.37     EL    835324  HISTORICAL_PRICES
# 15901  296.64  297.0600  293.2500  295.75     EL   1010239  HISTORICAL_PRICES
# 15902  296.20  299.2411  294.7500  296.76     EL   1182658  HISTORICAL_PRICES
# 15903  298.43  298.4500  294.1550  295.14     EL    989836  HISTORICAL_PRICES
# 15918  298.28  299.7000  297.3300  299.34     EL    843254  HISTORICAL_PRICES
#
# ...

# %%
#finding out the mean values of each property for a specific symbol
df.groupby("symbol").mean()
# Out:
#              close        high         low        open        volume  subkey  \
# symbol
# AAPL    133.031235  134.338668  131.597799  132.971142  9.244356e+07     NaN
# ABBV    111.525890  112.408128  110.510210  111.430613  6.683719e+06     NaN
# ABT     118.376319  119.376617  117.312692  118.259141  5.481220e+06     NaN
# ACN     283.502577  285.447993  281.376091  283.343374  1.938265e+06     NaN
# ADBE    522.780552  527.463542  517.012758  522.360928  2.254529e+06     NaN
# ...            ...         ...         ...         ...           ...     ...
# V       224.506319  226.594376  222.682251  224.615301  8.170018e+06     NaN
# VZ       56.652761   57.020863   56.339792   56.671585  1.745473e+07     NaN
# WFC      41.596933   42.082665   41.003031   41.495828  3.042450e+07     NaN
# WMT     140.534417  141.560829  139.648348  140.507301  8.348120e+06     NaN
# XOM      56.526626   57.199311   55.836446   56.480821  2.573313e+07     NaN
#
# ...

# %%
file = open("/Users/ani/Downloads/Stock List.csv")
file1 = pd.read_csv(file)
date = file1["date"].str[5:7]
freq = date.value_counts(ascending = True)
freq.sort_index(inplace = True)
x = freq.index
y = freq
plt.plot(x,y,marker = "o")
plt.show()
for x1 in range(8):
    print(x[x1], y[x1])
# Out:
# 01 1938
# 02 1938
# 03 2346
# 04 2142
# 05 2040
# 06 2244
# 07 2142
# 08 1834

# %%
file = open("/Users/ani/Downloads/Stock List.csv")
file1 = pd.read_csv(file)
file1 = file1[file1["symbol"]=="AAPL"]
date = file1["date"].str[5:7]
freq = date.value_counts(ascending = True)
freq.sort_index(inplace = True)
x = freq.index
y = freq
plt.plot(x,y,marker = "^")
plt.show()
for x1 in range(8):
    print(x[x1], y[x1])

# %%
file = open("/Users/ani/Downloads/Stock List.csv")
file1 = pd.read_csv(file)
z = input()
print(z)
file1 = file1[file1["symbol"]==z]
date = file1["label"].str[:3]
freq = date.value_counts(ascending = True)
freq.sort_index(inplace = True)
x = freq.index
y = freq
plt.plot(x,y,marker = "*")
plt.show()
for x1 in range(8):
    print(x[x1], y[x1])
